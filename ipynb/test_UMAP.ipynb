# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import networkx as nx
import umap
# %matplotlib inline

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
reducer = umap.UMAP(n_neighbors=30, min_dist=0.1, n_components=2, metric='correlation')
(fig, subplots) = plt.subplots(4, 3, figsize=(15, 8))

ax = subplots[0][0]
section = 'P1.1'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[0][1]
section = 'P1.2'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[0][2]
section = 'P1.3'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[1][0]
section = 'P2.1'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[1][1]
section = 'P2.3'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[1][2]
section = 'P2.4'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])
####################
ax = subplots[2][0]
section = 'P3.1'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[2][1]
section = 'P3.2'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[2][2]
section = 'P3.3'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])
#######################
ax = subplots[3][0]
section = 'P4.1'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[3][1]
section = 'P4.2'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

ax = subplots[3][2]
section = 'P4.3'
datadir = '/home/garner1/Work/dataset/SSF/prostate-twelve'
filename = datadir+'/'+section+'.tsv'
df = pd.read_csv(filename, sep='\t', header=0, index_col=0) # read the gene X position count-matrix and transpose to have rows<cols
df = df.div( df.sum(axis=0)+1, axis=1 ) #normalize to probabilities the transcriptome at each position
data = df.values.transpose()      
embedding = reducer.fit_transform(data)
ax.scatter(embedding[:, 0], embedding[:, 1])

plt.show()

# %%
mat = umap.umap_.fuzzy_simplicial_set(data, 10, np.random.RandomState(10), 
                                      'correlation', local_connectivity=1).todense()

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

n_samples = 300
n_components = 2
(fig, subplots) = plt.subplots(3, 5, figsize=(15, 8))
perplexities = [5, 30, 50, 100]
n_neighbors = [1,5,10,15]

X, y = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)

red = y == 0
green = y == 1

ax = subplots[0][0]
ax.scatter(X[red, 0], X[red, 1], c="r")
ax.scatter(X[green, 0], X[green, 1], c="g")
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

for i, neighbors in enumerate(n_neighbors):
    ax = subplots[0][i + 1]

    t0 = time()
    reducer = umap.UMAP(n_neighbors=n_neighbors, min_dist=0.1, n_components=2, metric='euclidean')
    Y = reducer.fit_transform(X)
    t1 = time()
    print("circles, neighbors=%d in %.2g sec" % (neighbors, t1 - t0))
    ax.set_title("Neighbors=%d" % neighbors)
    ax.scatter(Y[red, 0], Y[red, 1], c="r")
    ax.scatter(Y[green, 0], Y[green, 1], c="g")
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')

# Another example using s-curve
X, color = datasets.samples_generator.make_s_curve(n_samples=300, random_state=0)

ax = subplots[1][0]
ax.scatter(X[:, 0], X[:, 2], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, neighbors in enumerate(n_neighbors):
    ax = subplots[1][i + 1]

    t0 = time()
    reducer = umap.UMAP(n_neighbors=n_neighbors, min_dist=0.1, n_components=2, metric='euclidean')
    Y = reducer.fit_transform(X)
    t1 = time()
    print("S-curve, neighbors=%d in %.2g sec" % (neighbors, t1 - t0))

    ax.set_title("Neighbors=%d" % neighbors)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    
    
# Another example using a 2D uniform grid
x = np.linspace(0, 1, int(np.sqrt(n_samples)))
xx, yy = np.meshgrid(x, x)
X = np.hstack([
    xx.ravel().reshape(-1, 1),
    yy.ravel().reshape(-1, 1),
])
color = xx.ravel()
ax = subplots[2][0]
ax.scatter(X[:, 0], X[:, 1], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, neighbors in enumerate(n_neighbors):
    ax = subplots[2][i + 1]

    t0 = time()
    reducer = umap.UMAP(n_neighbors=n_neighbors, min_dist=0.1, n_components=2, metric='euclidean')
    Y = reducer.fit_transform(X)
    t1 = time()
    print("uniform grid, neighbors=%d in %.2g sec" % (neighbors, t1 - t0))

    ax.set_title("Neighbors=%d" % neighbors)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# /home/garner1/anaconda2/lib/python2.7/site-packages/umap/umap_.py:1362: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   "n_neighbors is larger than the dataset size; truncating to "
# circles, neighbors=1 in 1.3 sec
# /home/garner1/anaconda2/lib/python2.7/site-packages/umap/umap_.py:1362: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   "n_neighbors is larger than the dataset size; truncating to "
# circles, neighbors=5 in 1.3 sec
# /home/garner1/anaconda2/lib/python2.7/site-packages/umap/umap_.py:1362: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   "n_neighbors is larger than the dataset size; truncating to "
# circles, neighbors=10 in 1.3 sec
# ...

# %%
print(__doc__)

from time import time

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter

from sklearn import manifold, datasets

# Next line to silence pyflakes. This import is needed.
Axes3D

n_points = 1000
X, color = datasets.samples_generator.make_s_curve(n_points, random_state=0)
n_neighbors = 10
n_components = 2

fig = plt.figure(figsize=(15, 8))
plt.suptitle("Manifold Learning with %i points, %i neighbors"
             % (1000, n_neighbors), fontsize=14)


ax = fig.add_subplot(251, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.view_init(4, -72)

t0 = time()
Y = manifold.Isomap(n_neighbors, n_components).fit_transform(X)
t1 = time()
print("Isomap: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(252)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("Isomap (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')


t0 = time()
mds = manifold.MDS(n_components, max_iter=100, n_init=1)
Y = mds.fit_transform(X)
t1 = time()
print("MDS: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(253)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("MDS (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')


t0 = time()
se = manifold.SpectralEmbedding(n_components=n_components,
                                n_neighbors=n_neighbors)
Y = se.fit_transform(X)
t1 = time()
print("SpectralEmbedding: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(254)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("SpectralEmbedding (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

t0 = time()
tsne = manifold.TSNE(n_components=n_components, init='pca', random_state=0, perplexity=50)
Y = tsne.fit_transform(X)
t1 = time()
print("t-SNE: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(2, 5, 8)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("t-SNE (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

t0 = time()
reducer = umap.UMAP(n_neighbors=30, min_dist=0.5, n_components=2, metric='euclidean')
Y = reducer.fit_transform(X)
t1 = time()
print("UMAP: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(2, 5, 9)
plt.scatter(Y[:, 0], Y[:, 1], c=color, cmap=plt.cm.Spectral)
plt.title("UMAP (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Isomap: 0.37 sec
# MDS: 1.3 sec
# SpectralEmbedding: 0.1 sec
# t-SNE: 17 sec
# UMAP: 2.7 sec

# %%
from numpy import linspace,pi,cos,sin
samples = 1000
phi = linspace(0,2*pi,samples)
x = sin(phi)+2*sin(2*phi)
y = cos(phi)-2*cos(2*phi)
z = -sin(3*phi)

data = np.zeros((samples,3))
data[:,0] = x
data[:,1] = y
data[:,2] = z

from pylab import scatter,subplot,cm,show
from numpy import abs
s=abs(((y+3)+2)*10)
plt.figure()
scatter(x,y,c=x,s=s,edgecolor='w',cmap=cm.gist_rainbow)

t0 = time()
reducer = umap.UMAP(n_neighbors=100, min_dist=0.1, n_components=2, metric='euclidean')
Y = reducer.fit_transform(data)
t1 = time()
print("UMAP: %.2g sec" % (t1 - t0))
plt.figure()
plt.scatter(Y[:, 0], Y[:, 1],c=x,s=s,edgecolor='w',cmap=cm.gist_rainbow)
plt.title("UMAP (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

show()
# Out:
# UMAP: 3.3 sec

# %%
Y.shape
# Out:
# (1000, 2)
